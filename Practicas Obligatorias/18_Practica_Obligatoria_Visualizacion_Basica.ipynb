# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: VISUALIZACION BASICA

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste en un único ejercicio de construcción de gráficas. Descarga este notebook en tu ordenador y trabaja en local. Ten en cuenta que tendrás que descar los directorios de imágenes y datos adicionales, si los hubiera.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## #1

# %% [markdown]
# ### #1.1

# %% [markdown]
# Carga el dataset de casas de California que está en la ruta "./data/california_cities.csv". Muestra parte de su contenido y su descripción. Deshazte de las filas con nulos.

# %%
cities = pd.read_csv("./data/california_cities.csv")
cities = cities.dropna()
cities
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 0             0     Adelanto  34.576111 -117.432778        875.0
# 1             1  AgouraHills  34.153333 -118.761667        281.0
# 4             4     Alhambra  34.081944 -118.135000        150.0
# 5             5   AlisoViejo  33.575000 -117.725556        127.0
# 6             6      Alturas  41.487222 -120.542500       1332.0
# ..          ...          ...        ...         ...          ...
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0          2871.0             31765            56.027           56.009
# 1           922.0             20330             7.822            7.793
# 4           492.0             83089             7.632            7.631
# 5           417.0             47823             7.472            7.472
# 6          4370.0              2827             2.449            2.435
# ..            ...               ...               ...              ...
# 477          98.0              2933             1.531            1.531
# 478        2582.0              7765            10.053            9.980
# 479          59.0             64925            14.656           14.578
# 480        2618.0             51367            27.893           27.888
# 481        3369.0             20700            40.015           40.015
#
#      area_water_sq_mi  area_total_km2  area_land_km2  area_water_km2  \
# 0               0.018         145.107        145.062           0.046
# 1               0.029          20.260         20.184           0.076
# 4               0.001          19.766         19.763           0.003
# 5               0.000          19.352         19.352           0.000
# 6               0.014           6.342          6.306           0.036
# ..                ...             ...            ...             ...
# 477             0.000           3.966          3.966           0.000
# 478             0.073          26.036         25.847           0.188
# 479             0.078          37.959         37.758           0.201
# 480             0.005          72.244         72.231           0.013
# 481             0.000         103.639        103.639           0.000
#
#      area_water_percent
# 0                  0.03
# 1                  0.37
# 4                  0.01
# 5                  0.00
# 6                  0.57
# ..                  ...
# 477                0.00
# 478                0.72
# 479                0.53
# 480                0.02
# 481                0.00
#
# [427 rows x 14 columns]

# %% [markdown]
# ### #1.2
#
# Recrea la siguiente figura, para ello construye en apartados separados cada gráfico y luego haz un apartado en el que se junten los cuatro. Las figuras son:
# 1. Las ciudades más pobladas, con los numeros de las poblaciones (tendrás que usar texto y recordar que para centrarlos se necesita poner el argumento `ha` a "center"). (Colores: azul, gris, aceituna, marrón, con trasparencia)
# 2. Histograma del área total ocupada por las ciudades. (50 bins, fuente = "Bradley Hand itc", tamaño 18, color azul acero)
# 3. El scatter de área de agua de un ciudad con su poblacion.
# 4. El boxplot de la altura de las ciudades.

# %% [markdown]
# ![figura_ejempo.png](attachment:figura_ejempo.png)

# %%
valores_columna_1_y_2 = cities[['city', 'population_total']]
f_ordenado =valores_columna_1_y_2.sort_values(by=['population_total','city'], ascending=[False, False])
f_ordenado
# Out:
#            city  population_total
# 239  LosAngeles           3884307
# 367    SanDiego           1345895
# 359  Sacramento            466488
# 9       Anaheim            336000
# 386    SantaAna            324528
# ..          ...               ...
# 366    SandCity               334
# 190    Industry               219
# 7    AmadorCity               185
# 448      Vernon               112
# 327      Pomona                 1
#
# [427 rows x 2 columns]

# %%
ciudades = ['Los Angeles', 'San Diego', 'San Jose','San Francisco', 'Fresno']
poblaciones = [3884307, 1345895,1000536 ,837442,509039 ]
colores = ['blue', 'gray', 'olive', 'brown']




plt.figure(figsize=(8, 6))
plt.bar(ciudades, poblaciones, color=colores, alpha=0.7)
plt.ylim(0,5000000)
for barra, poblacion in zip(barras, poblaciones):
    plt.text(barra.get_x() + barra.get_width() / 2 - 0.1, barra.get_height() + 0.1, str(poblacion), ha='center')
plt.title('Ciudades Más Pobladas')
plt.xlabel('Ciudades')
plt.ylabel('Población')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(cities["area_total_km2"], bins=50, color='steelblue', edgecolor='black')

plt.title('Histograma del Área Total Ocupada por las Ciudades', fontsize=18, fontname='Bradley Hand ITC')
plt.xlabel('Área Total km2', fontsize=14)
plt.ylabel('Frecuencia', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12);

# %%
plt.figure(figsize=(10, 6))
plt.scatter(cities["area_water_km2"], cities["population_total"], color='g', alpha=0.5
            )


plt.title('Relación entre Área de Agua y Población de Ciudades')
plt.xlabel('Área de Agua (km²)')
plt.ylabel('Población')
# Out:
# Text(0, 0.5, 'Población')

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(cities["elevation_ft"], vert=False)

plt.title('Boxplot de la Altura de las Ciudades')
plt.xlabel('Altura (metros)')
# Out:
# Text(0.5, 0, 'Altura (metros)')

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))


axs[0, 0].hist(cities["area_total_km2"], bins=30, color='skyblue', edgecolor='black')
axs[0, 0].set_title('Histograma')
plt.figure(figsize=(10, 6))

axs[0, 1].bar(range(len(ciudades)), poblacion, color='orange')
axs[0, 1].set_title('Diagrama de Barras')
axs[0, 1].set_xticks(range(len(ciudades)))

axs[1, 0].scatter(cities["area_water_km2"], cities["population_total"], color='g', alpha=0.5)
axs[1, 0].set_title('Scatter Plot')


axs[1, 1].boxplot(cities["elevation_ft"], vert=False)
axs[1, 1].set_title('Boxplot')

plt.tight_layout()
plt.savefig('figura_completa.png')
plt.show()

# %% [markdown]
# ### #1.3
#
# Graba la figura en un archivo y sube el archivo a tu repo personal también.
