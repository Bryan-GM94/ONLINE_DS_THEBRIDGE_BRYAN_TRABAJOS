# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = "Accidentes automovilisticos Madrid 2012"

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown
tema = "Determinar ¿Cuál es el factor por que se producen accidentes automovilisticos en Madrid del año 2012"

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %%
# Escribe tu hipótesis principal en Markdown
hipotesis_1 = "La relación que existe de las variables de horas con las zonas de la ciudad en relacion de los accidentes de transito"

# %%
# Escribe más hipótesis si las hubiera en Markdown
# hipotesis_2 = " La incidencia que tiene la edad para provocar accidentes de transito"
# hipotesis_3 = "Relacion entre el tipo de automovil  con el accidente"
# hipotesis_4 = "Relacion entre el sexo y los días de la semama "
# hipotesis_5 = ""
# ...

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
# guarda en variables los datasets y su fuente
df= pd.read_excel("./data/2012_Accidentalidad.xlsx")
df_1 = pd.DataFrame(df)
fuente_1 = "https://datos.gob.es/en/catalogo/l01280796-accidentes-de-trafico-de-la-ciudad-de-madrid1"
# df_2 = pd.DataFrame()
# fuente_2 = ""
# df_3 = pd.DataFrame()
# fuente_3 = ""
# df_4 = pd.DataFrame()
# fuente_4 = ""
# df_5 = pd.DataFrame()
# fuente_5 = ""
# ...

# %%
df_1
# Out:
#            FECHA     RANGO HORARIO DIA SEMANA                        DISTRITO  \
# 0     2012-01-01    DE 2:00 A 2:59    DOMINGO  CENTRO
# 1     2012-01-01    DE 2:00 A 2:59    DOMINGO  CENTRO
# 2     2012-01-01    DE 2:00 A 2:59    DOMINGO  CENTRO
# 3     2012-01-01    DE 2:00 A 2:59    DOMINGO  CENTRO
# 4     2012-01-01    DE 2:00 A 2:59    DOMINGO  PUENTE DE VALLECAS
# ...          ...               ...        ...                             ...
# 26977 2012-12-31  DE 21:00 A 21:59      LUNES  CENTRO
# 26978 2012-12-31  DE 21:00 A 21:59      LUNES  CENTRO
# 26979 2012-12-31  DE 21:00 A 21:59      LUNES  VILLAVERDE
# 26980 2012-12-31  DE 21:00 A 21:59      LUNES  VILLAVERDE
# 26981 2012-12-31  DE 23:00 A 23:59      LUNES  FUENCARRAL-EL PARDO
#
#                                          LUGAR ACCIDENTE  Nº  Nº PARTE  \
# 0      CALLE DE LA PRINCESA NUM                      ...  10   2012/98
# 1      CALLE DE LA PRINCESA NUM                      ...  10   2012/98
# ...

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
df_1.head()
# Out:
#        FECHA   RANGO HORARIO DIA SEMANA                        DISTRITO  \
# 0 2012-01-01  DE 2:00 A 2:59    DOMINGO  CENTRO
# 1 2012-01-01  DE 2:00 A 2:59    DOMINGO  CENTRO
# 2 2012-01-01  DE 2:00 A 2:59    DOMINGO  CENTRO
# 3 2012-01-01  DE 2:00 A 2:59    DOMINGO  CENTRO
# 4 2012-01-01  DE 2:00 A 2:59    DOMINGO  PUENTE DE VALLECAS
#
#                                      LUGAR ACCIDENTE  Nº  Nº PARTE  \
# 0  CALLE DE LA PRINCESA NUM                      ...  10   2012/98
# 1  CALLE DE LA PRINCESA NUM                      ...  10   2012/98
# 2  CALLE DE LA PRINCESA NUM                      ...  10   2012/98
# 3  CALLE DE LA PRINCESA NUM                      ...  10   2012/98
# 4  AVENIDA DE SAN DIEGO NUM                      ...  96  2012/118
#
#   CPFA Granizo CPFA Hielo CPFA Lluvia  ... CPSV Grava Suelta CPSV Hielo  \
# 0           NO         NO          NO  ...                NO         NO
# 1           NO         NO          NO  ...                NO         NO
# ...

# %%
# Siguiente dataset...
# df_2.head()
